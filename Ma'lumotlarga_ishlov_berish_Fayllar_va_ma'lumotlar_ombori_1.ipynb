# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/Ma'lumotlarga_ishlov_berish_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# fayllar ketma-ketligida ochilishi
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df.shape
# Out:
# (3000, 9)

# %%
df1 = pd.read_excel("uzbekistan.xlsx")
df1

# %%
# index_col = 0 orqali, 0 o'rinda turgan columnni indexga o'zgartirdik. va names orqali nomlarini ham o'zgartirdik
df1 = pd.read_excel("uzbekistan.xlsx", index_col = 0, names = ["Hudud", "Maydon", "Aholi"])
df1

# %%
df2 = pd.read_csv("automobile_data.csv", sep = ";")
df2

# %%
# indexini companyga o'zgartirdik, nrows = df2.head(10)
df2 = pd.read_csv("automobile_data.csv", index_col = "company", nrows = 10)
df2

# %%
df3 = pd.read_excel("uzbekistan.xlsx", index_col = 0, names = ["Hudud", "Maydon", "Aholi"])
df3

# %%
# boshqa turdagi df ni, turi hamda qayta nomlash uchun ishlatiladi
# bu "to" orqali amalga oshiriladi
df3 = pd.read_excel("uzbekistan.xlsx", index_col = 0, names = ["Hudud", "Maydon", "Aholi"])
df3.to_csv("newuzbekistan.csv")

# %%
# index saqlanmaydi xotira uchun index_col = False uchun
df3 = pd.read_csv("newuzbekistan.csv", index_col = False)
df3

# %%
# index saqlanmaydi xotira uchun index_col = False uchun
df3 = pd.read_csv("newuzbekistan.csv", index_col = False)
df3# tools/node/ papkasiga saqlandi
df3 = pd.read_excel("uzbekistan.xlsx", index_col = 0, names = ["Hudud", "Maydon", "Aholi"])
df3.to_csv("tools/node/newuzbekistan.csv")

# %%
# index saqlanmaydi xotira uchun index_col = False uchun
df3 = pd.read_csv("newuzbekistan.csv", index_col = False)
df3# tools/node/ papkasiga saqlandi
df3 = pd.read_excel("uzbekistan.xlsx", index_col = 0, names = ["Hudud", "Maydon", "Aholi"])
df3.to_csv("tools/node/newuzbekistan.csv")# data.h5 formatidagi HDF Storega saqladik, hdfobj nom ostida dataframe
hdfobj = pd.HDFStore("data.h5")

# %%
# put orqali df2 ma'lumotlari hdfobj uchun saqlandi
hdfobj.put("uzdata", df2)

# %%
# put orqali df3 ma'lumotlari hdfobj uchun saqlandi
hdfobj.put("cardata", df3)

# %%
# hdfobj ning kiritilgan kalitlarini ko'rish uchun
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
# kalit orqali ochish datani
hdfobj["uzdata"]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# hdfobj file yopiladi
# ochish uchun esa hdfobj = pd.HDFStore("data.h5") ni qaytadan kiritamiz
hdfobj.close()

# %%
# qayta ochildi
hdfobj = pd.HDFStore("data.h5")

# %%
# web-sahifadan ko'chirib olish faqat jadvallarni oladi
tashkent = pd.read_html("http://en.wikipedia.org/wiki/Tashkent")

# %%
# dataframe ning jadvallar soni ko'rsatadi
len(tashkent)
# Out:
# 18

# %%
# 5-jadvalni ochib beradi
tashkent[5]
# Out:
#    Climate data for Tashkent (1991–2020, extremes 1867–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6              Average extreme snow depth cm (inches)
# 7                                  Average rainy days
# 8                                  Average snowy days
# 9                       Average relative humidity (%)
# 10                        Mean monthly sunshine hours
# 11                        Source 1: Pogoda.ru.net[54]
# 12                                 Source 2: NOAA[55]
#
#                                                               \
#                             Jan                          Feb
# ...

# %%
tashkent[6]
# Out:
#                                                     0  \
# 0   YearPop.±% p.a.1897 155,673— 1959 911,930+2.89...
# 1                                                Year
# 2                                                1897
# 3                                                1959
# 4                                                1970
# 5                                                1979
# 6                                                1983
# 7                                                1989
# 8                                                1991
# 9                                                1995
# 10                                               2000
# 11                                               2001
# 12                                               2002
# 13                                               2003
# 14                                               2004
# 15                                               2005
# ...

# %%
# JSON formatidagi jadvallarni ochish va o'qish
# JSON eng mashhur format hisoblanadi
pd.read_json("")
