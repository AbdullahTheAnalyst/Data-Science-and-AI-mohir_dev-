# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/Ma'lumotlarga_ishlov_berish_Ma'lumotlarni_tayyorlash_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("database.csv")
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
import datetime as dt

# %%
hozir = dt.datetime.now()

# %%
dt.datetime.year
# Out:
# <attribute 'year' of 'datetime.date' objects>

# %%
type(hozir)
# Out:
# datetime.datetime

# %%
print(hozir)
# Out:
# 2024-11-21 05:25:11.934917

# %%
hozir.hour
# Out:
# 5

# %%
hozir.minute
# Out:
# 25

# %%
hozir.weekday()
# Out:
# 3

# %%
hozir.year
# Out:
# 2024

# %%
hozir.fold
# Out:
# 0

# %%
hozir.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2024, week=47, weekday=4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
sana = df.at[0, "Date"]

# %%
# object qiymatni datetime formatiga o'tkazish uchun
# bu hammsi  bunaqa formatda bo'lmagani uchun natija yaxshi natija bermaydi
pd.to_datetime(df["Date"], format = "%m/%d/%Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-890100cba09f> in <cell line: 3>()
#       1 # object qiymatni datetime formatiga o'tkazish uchun
#       2 # bu hammsi  bunaqa formatda bo'lmagani uchun natija yaxshi natija bermaydi
# ----> 3 pd.to_datetime(df["Date"], format = "%m/%d/%Y")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# ...

# %%
# bu muammoni yechishda aynan bir xil yechim yo'q
# str bo'lgan Dateni uzunligini bilib olamiz
df["Date"].str.len()
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 23407    10
# 23408    10
# 23409    10
# 23410    10
# 23411    10
# Name: Date, Length: 23412, dtype: int64

# %%
# 3 ta noodatiy bo'lgan qiymatlar mavjud
df["Date"].str.len().value_counts()
# Out:
# Date
# 10    23409
# 24        3
# Name: count, dtype: int64

# %%
df[df["Date"].str.len() > 10].index
# Out:
# Index([3378, 7512, 20650], dtype='int64')

# %%
df[df["Date"].str.len() == 24]
# Out:
#                            Date                      Time  Latitude  \
# 3378   1975-02-23T02:58:41.000Z  1975-02-23T02:58:41.000Z     8.017
# 7512   1985-04-28T02:53:41.530Z  1985-04-28T02:53:41.530Z   -32.998
# 20650  2011-03-13T02:23:34.520Z  2011-03-13T02:23:34.520Z    36.344
#
#        Longitude        Type  Depth  Depth Error  Depth Seismic Stations  \
# 3378     124.075  Earthquake  623.0          NaN                     NaN
# 7512     -71.766  Earthquake   33.0          NaN                     NaN
# 20650    142.344  Earthquake   10.1         13.9                   289.0
#
#        Magnitude Magnitude Type  ...  Magnitude Seismic Stations  \
# 3378         5.6             MB  ...                         NaN
# 7512         5.6             MW  ...                         NaN
# 20650        5.8            MWC  ...                         NaN
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# ...

# %%
df.loc[3378, "Date"] = "02/23/1975"
df.loc[7512, "Date"] = "04/28/1985"
df.loc[20650, "Date"] = "03/13/2011"

# %%
df["Date"].str.len().value_counts()
# Out:
# Date
# 10    23412
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.loc[2095, "Date"] = "01/01/1971"

# %%
# alohida df ga joylashtirish uchun
df["date_new"] = pd.to_datetime(df["Date"], format = "%m/%d/%Y")

# %%
df.tail()
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake  12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# ...

# %%
df.at[0, "date_new"]
# Out:
# Timestamp('1965-01-02 00:00:00')

# %%
df.at[0, "date_new"].weekday()
# Out:
# 5

# %%
# oylarni chiqarishimiz mumkin
df["Months"] = df["date_new"].dt.month

# %%
# statistika uchun (mart oyida eng ko'p zilzila bo'lar ekan)
df["Months"].value_counts()
# Out:
# Months
# 3     2114
# 8     2014
# 12    2001
# 11    1987
# 9     1984
# 4     1971
# 5     1964
# 10    1952
# 1     1892
# 7     1880
# 2     1829
# 6     1824
# Name: count, dtype: int64

# %%
df["Weekday"] = df["date_new"].dt.weekday

# %%
# eng ko'p shanba kuni zilzila bo'lar ekan
df["Weekday"].value_counts()
# Out:
# Weekday
# 5    3433
# 2    3431
# 4    3362
# 0    3349
# 3    3306
# 6    3287
# 1    3244
# Name: count, dtype: int64

# %%
# bu formatga ham hamma rows ichidagi time elementlari tushmaydi
# endi Time columnni ham data cleaning qilishimiz kerak
df["time_new"] = pd.to_datetime(df["Time"], format = "%H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-ff3fa0fc04d6> in <cell line: 3>()
#       1 # bu formatga ham hamma rows ichidagi time elementlari tushmaydi
#       2 # endi Time columnni ham data cleaning qilishimiz kerak
# ----> 3 df["time_new"] = pd.to_datetime(df["Time"], format = "%H:%M:%S")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df["Time"].str.len()
# Out:
# 0        8
# 1        8
# 2        8
# 3        8
# 4        8
#         ..
# 23407    8
# 23408    8
# 23409    8
# 23410    8
# 23411    8
# Name: Time, Length: 23412, dtype: int64

# %%
df[df["Time"].str.len() > 8]
# Out:
#              Date                      Time  Latitude  Longitude        Type  \
# 3378   02/23/1975  1975-02-23T02:58:41.000Z     8.017    124.075  Earthquake
# 7512   04/28/1985  1985-04-28T02:53:41.530Z   -32.998    -71.766  Earthquake
# 20650  03/13/2011  2011-03-13T02:23:34.520Z    36.344    142.344  Earthquake
#
#        Depth  Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 3378   623.0          NaN                     NaN        5.6             MB
# 7512    33.0          NaN                     NaN        5.6             MW
# 20650   10.1         13.9                   289.0        5.8            MWC
#
#        ...  Horizontal Error  Root Mean Square          ID  Source  \
# 3378   ...               NaN               NaN  USP0000A09      US
# 7512   ...               NaN              1.30  USP0002E81      US
# 20650  ...               NaN              1.06  USP000HWQP      US
#
#        Location Source  Magnitude Source    Status   date_new Months Weekday
# ...

# %%
df.loc[3378, "Time"] = "02:58:41"
df.loc[7512, "Time"] = "02:53:41"
df.loc[20650, "Time"] = "02:23:34"

# %%
df["Time"].str.len().value_counts()
# Out:
# Time
# 8    23412
# Name: count, dtype: int64

# %%
df["Time_new"] = pd.to_datetime(df["Time"], format = "%H:%M:%S")
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...
