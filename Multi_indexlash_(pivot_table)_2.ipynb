# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/Multi_indexlash_(pivot_table)_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Multi indexlash
#
# Hierarchial indexing
#
# Bir nechta indexdan tashkil topgan

# %%
# bu Multi indexlash bizga juda katta database ga ishlov berish uchun kerak bo'ladi
# Odatiy Series to'plam
data = pd.Series(np.random.randn(9), index = ["a",
                                              "a",
                                              "a",
                                              "b",
                                              "b",
                                              "c",
                                              "c",
                                              "d",
                                              "d",
                                              ])
data
# Out:
# a   -1.438600
# a    0.273812
# a   -0.550314
# b   -1.985547
# b    1.367370
# c   -0.108385
# c   -0.711387
# d    0.129849
# d   -0.420025
# dtype: float64

# %%
data.index
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')

# %%
# buni multi - indexga alishtiramiz
# yuqori masshtabli db uchun guruhlashga juda yordam beradi
data1 = pd.Series(np.random.randn(9), index = [["a", "a", "a", "b", "b", "c", "c", "d", "d"],
                                              [1, 2, 3, 1, 3, 1, 2, 2, 3]])
data1
# Out:
# a  1   -1.259966
#    2   -0.040916
#    3    0.725736
# b  1    0.685902
#    3   -0.056911
# c  1    0.472592
#    2    0.433679
# d  2    0.902761
#    3   -1.716570
# dtype: float64

# %%
data1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
# faqat c indexiga tegishli datani ajratib olamiz
data1["c"]
# Out:
# 1    0.472592
# 2    0.433679
# dtype: float64

# %%
# ko'p indexini ajratib olish
data1["c" : "d"]
# Out:
# c  1    0.472592
#    2    0.433679
# d  2    0.902761
#    3   -1.716570
# dtype: float64

# %%
data1["a" : "c"]
# Out:
# a  1   -1.259966
#    2   -0.040916
#    3    0.725736
# b  1    0.685902
#    3   -0.056911
# c  1    0.472592
#    2    0.433679
# dtype: float64

# %%
# barcha 3-indexga tegishli elementlarni ajratib olish
data1.loc[ : , 3]
# Out:
# a    0.725736
# b   -0.056911
# d   -1.716570
# dtype: float64

# %%
# barcha b va c indexdagi elementlar
data1.loc[["b", "c"]]
# Out:
# b  1    0.685902
#    3   -0.056911
# c  1    0.472592
#    2    0.433679
# dtype: float64

# %%
# unstack va stack usullari juda foydali hisoblanadi
# unstack -> bu multi-indexdan dataframega sochib yuboradi
# unstack -> sochilgan Seriesni df ko'rinishiga qaytaradi
data1.unstack()
# Out:
#           1         2         3
# a -1.259966 -0.040916  0.725736
# b  0.685902       NaN -0.056911
# c  0.472592  0.433679       NaN
# d       NaN  0.902761 -1.716570

# %%
# stack -> df.ni yig'ilgan Series.ga o'giradi
data1.unstack().stack()
# Out:
# a  1   -1.259966
#    2   -0.040916
#    3    0.725736
# b  1    0.685902
#    3   -0.056911
# c  1    0.472592
#    2    0.433679
# d  2    0.902761
#    3   -1.716570
# dtype: float64

# %% [markdown]
# Dunyo shaharlarining havo va suv sifati to'g'risida dataset

# %%
# git hubdan repository.ni yuklab olish
! git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 20.24 MiB | 6.02 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (13/13), done.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df.head()
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# 3      62.364130          28.612717
# 4      36.621622          61.299435

# %%
# har doim data cleaning.dan oldin albatta data haqida ma'lumotlari haqida info ol
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
# ishni column name.ni to'g'irlashdan boshlaymiz ("" ichida yozilgan xatosi)
index_col = ["City", "Region", "Country", "AirQuality", "WaterPollution"]
df.columns = index_col
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
# Region va Country ichida hamma element "" ichida yozilgan va buni to'g'irlashimiz kerak
# .map(lambda x: x.replace('"', '')) -> " ning o'rnida bo'sh qoldirish uchun dastur
df["Region"] = df["Region"].map(lambda x: x.replace('"', ''))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
# Region va Country ichida hamma element "" ichida yozilgan va buni to'g'irlashimiz kerak
# .map(lambda x: x.replace('"', '')) -> " ning o'rnida bo'sh qoldirish uchun dastur
df["Country"] = df["Country"].map(lambda x: x.replace('"', ''))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
# yuqorida update qilingan data.ni yangi csv file.ga save qilish kerak
# index = False ->boshqa index paydo bo'lishini oldini oladi
df.to_csv("Updated_dataset", index = False)

# %%
# bui bajarsak, Germany oldida space mavjudligini ko'rishimiz mumkin
df[df["Country"] == "Germany"]
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, AirQuality, WaterPollution]
# Index: []

# %%
df["Country"][100]
# Out:
# ' India'

# %%
df["Country"] = df["Country"].map(lambda x: x.strip())
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df["Country"][100]
# Out:
# 'India'

# %%
# germany.ga tegishli data.lar chiqardik
df[df["Country"] == "Germany"]
# Out:
#                         City                   Region  Country  AirQuality  \
# 3                     Berlin                           Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia  Germany   70.454545
# ...                      ...                      ...      ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria  Germany  100.000000
# 2727                  Buckow              Brandenburg  Germany   87.500000
# 3942                  Erfurt                Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria  Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# 28         27.777778
# ...

# %%
# uzbekistanga.ga tegishli data.lar chiqardik
df[df["Country"] == "Uzbekistan"]
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %% [markdown]
# **pivot_table** orqali multi-indexlash

# %%
df.head(3)
# Out:
#                City                 Region                   Country  \
# 0     New York City               New York  United States of America
# 1  Washington, D.C.   District of Columbia  United States of America
# 2     San Francisco             California  United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000

# %%
# qiymatlati 'AirQuality', 'WaterPollution' bo'lgan pivot table
df1 = pd.pivot_table(df, index = ["Country", "City"], values=['AirQuality', 'WaterPollution'])

# %%
df1
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df1.index
# Out:
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
#             (     'Zambia',         'Lusaka'),
#             (     'Zambia',          'Mansa'),
#             (   'Zimbabwe',        'Bindura'),
#             (   'Zimbabwe',       'Bulawayo'),
#             (   'Zimbabwe',         'Harare'),
#             (   'Zimbabwe',       'Masvingo')],
# ...

# %%
df1.loc[["Uzbekistan", "Tajikistan", "Zambia"]]
# Out:
#                      AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent   56.451613       49.166667
# Tajikistan Dushanbe   41.666667       61.111111
# Zambia     Chingola   75.000000      100.000000
#            Kitwe       0.000000      100.000000
#            Lusaka     33.333333       98.076923
#            Mansa      75.000000       25.000000

# %%
df1["AirPollution"] = 100 - df1["AirQuality"]
df1["WaterQuality"] = 100 - df1["WaterPollution"]
df1
# Out:
#                       AirQuality  WaterPollution  AirPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000    100.000000
#             Herat      43.750000       31.250000     56.250000     68.750000
#             Kabul      18.421053       81.060606     81.578947     18.939394
#             Kandahar    0.000000       75.000000    100.000000     25.000000
# ...                          ...             ...           ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000     25.000000
#             Bulawayo   67.857143       71.428571     32.142857     28.571429
#             Harare     38.461538       87.500000     61.538462     12.500000
#             Masvingo   25.000000       62.500000     75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
# tepada index.larni rows orqali multi-indexladik
# endi esa column.larni multi-indexlab chiqamiz
df3 = pd.DataFrame(df1.values, index = df1.index, columns =
                   [["AIR", "AIR", "WATER", "WATER",],
                    ["AirQuality",	"AirPollution",	"WaterPollution",	"WaterQuality"]
                    ])
df3
# Out:
#                              AIR                       WATER
#                       AirQuality AirPollution WaterPollution WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000      50.000000    50.000000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Kandahar    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# Zimbabwe    Bindura    50.000000    75.000000      50.000000    25.000000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Masvingo   25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
df3["AIR"]
# Out:
#                       AirQuality  AirPollution
# Country     City
# Afghanistan Andkhoy    50.000000     50.000000
#             Farah     100.000000      0.000000
#             Herat      43.750000     31.250000
#             Kabul      18.421053     81.060606
#             Kandahar    0.000000     75.000000
# ...                          ...           ...
# Zambia      Mansa      75.000000     25.000000
# Zimbabwe    Bindura    50.000000     75.000000
#             Bulawayo   67.857143     71.428571
#             Harare     38.461538     87.500000
#             Masvingo   25.000000     62.500000
#
# [3895 rows x 2 columns]

# %%
df3["WATER"]
# Out:
#                       WaterPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy        50.000000     50.000000
#             Farah           0.000000    100.000000
#             Herat          56.250000     68.750000
#             Kabul          81.578947     18.939394
#             Kandahar      100.000000     25.000000
# ...                              ...           ...
# Zambia      Mansa          25.000000     75.000000
# Zimbabwe    Bindura        50.000000     25.000000
#             Bulawayo       32.142857     28.571429
#             Harare         61.538462     12.500000
#             Masvingo       75.000000     37.500000
#
# [3895 rows x 2 columns]

# %%
# ikki mavjud column.larning ismlariga nom berish uchun
df3.columns.names = ["Birinchi ustun:", "Ikkinchi ustun:"]
df3
# Out:
# Birinchi ustun:              AIR                       WATER
# Ikkinchi ustun:       AirQuality AirPollution WaterPollution WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000      50.000000    50.000000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Kandahar    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# Zimbabwe    Bindura    50.000000    75.000000      50.000000    25.000000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Masvingo   25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
# index nomlarini tekshirish
df3.index.names
# Out:
# FrozenList(['Davlat', 'Shahar'])

# %%
df3.index.names = ["Davlat", "Shahar"]
df3
# Out:
# Birinchi ustun:              AIR                       WATER
# Ikkinchi ustun:       AirQuality AirPollution WaterPollution WaterQuality
# Davlat      Shahar
# Afghanistan Andkhoy    50.000000    50.000000      50.000000    50.000000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Kandahar    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# Zimbabwe    Bindura    50.000000    75.000000      50.000000    25.000000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Masvingo   25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
# darajalarni o'zgartirish metodi
# ya'ni indexlarning o'rnini almashtirish
df3.swaplevel("Davlat", "Shahar")
# Out:
# Birinchi ustun:              AIR                       WATER
# Ikkinchi ustun:       AirQuality AirPollution WaterPollution WaterQuality
# Shahar   Davlat
# Andkhoy  Afghanistan   50.000000    50.000000      50.000000    50.000000
# Farah    Afghanistan  100.000000     0.000000       0.000000   100.000000
# Herat    Afghanistan   43.750000    31.250000      56.250000    68.750000
# Kabul    Afghanistan   18.421053    81.060606      81.578947    18.939394
# Kandahar Afghanistan    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Mansa    Zambia        75.000000    25.000000      25.000000    75.000000
# Bindura  Zimbabwe      50.000000    75.000000      50.000000    25.000000
# Bulawayo Zimbabwe      67.857143    71.428571      32.142857    28.571429
# Harare   Zimbabwe      38.461538    87.500000      61.538462    12.500000
# Masvingo Zimbabwe      25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
# indexlarni tartiblash
# level -> bu asl holati
# ascending = False -> teskari tartibda tartiblash
df3.sort_index(level = 0, ascending = False)
# Out:
# Birinchi ustun:              AIR                       WATER
# Ikkinchi ustun:       AirQuality AirPollution WaterPollution WaterQuality
# Davlat      Shahar
# Zimbabwe    Masvingo   25.000000    62.500000      75.000000    37.500000
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Bindura    50.000000    75.000000      50.000000    25.000000
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# ...                          ...          ...            ...          ...
# Afghanistan Kandahar    0.000000    75.000000     100.000000    25.000000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Andkhoy    50.000000    50.000000      50.000000    50.000000
#
# ...
