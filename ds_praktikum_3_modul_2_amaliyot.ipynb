# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/ds_praktikum_3_modul_2_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/melb_data.csv")
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13513     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13514  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13515     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13516   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13517   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13513           NaN     1981.0          NaN -37.90562   145.16761
# 13514         133.0     1995.0          NaN -37.85927   144.87904
# 13515           NaN     1997.0          NaN -37.85274   144.88738
# 13516         157.0     1920.0          NaN -37.85908   144.89299
# 13517         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13513  South-Eastern Metropolitan        7392.0
# 13514        Western Metropolitan        6380.0
# 13515        Western Metropolitan        6380.0
# 13516        Western Metropolitan        6380.0
# 13517        Western Metropolitan        6543.0
#
# [13518 rows x 21 columns]

# %%
# 1-VAZIFA. df dagi barcha ustunlardagiNaN qiymatlar sonini chiqaring
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea     6417
# YearBuilt        5344
# CouncilArea      1307
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# 2-VAZIFA. df barcha NaN qiymatlarni 0 bilan almashtiring
df.fillna(0)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13513     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13514  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13515     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13516   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13517   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               0.0        0.0        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               0.0        0.0        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13513           0.0     1981.0            0 -37.90562   145.16761
# 13514         133.0     1995.0            0 -37.85927   144.87904
# 13515           0.0     1997.0            0 -37.85274   144.88738
# 13516         157.0     1920.0            0 -37.85908   144.89299
# 13517         112.0     1920.0            0 -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13513  South-Eastern Metropolitan        7392.0
# 13514        Western Metropolitan        6380.0
# 13515        Western Metropolitan        6380.0
# 13516        Western Metropolitan        6380.0
# 13517        Western Metropolitan        6543.0
#
# [13518 rows x 21 columns]

# %%
# 3-VAZIFA. Quyidagi 2 ustun uchun o'rta qiymatlarni hisoblang:
# BuildingArea
# YearBuilt (butun son qaytishi kerak)
df["BuildingArea"].mean()
# Out:
# 152.12890349246587

# %%
df["YearBuilt"].mean()
# Out:
# 1964.896501101052

# %%
# 4-VAZIFA: BuildingArea va YearBuilt ustunlaridagi NaN qiymatlarni shu sutun uchun o'rta qiymatlar bilan almashtiring
df['BuildingArea'].fillna(df["BuildingArea"].mean())
# Out:
# 0        152.128903
# 1         79.000000
# 2        150.000000
# 3        152.128903
# 4        142.000000
#             ...
# 13513    152.128903
# 13514    133.000000
# 13515    152.128903
# 13516    157.000000
# 13517    112.000000
# Name: BuildingArea, Length: 13518, dtype: float64

# %%
df['YearBuilt'].fillna(df["YearBuilt"].mean())
# Out:
# 0        1964.896501
# 1        1900.000000
# 2        1900.000000
# 3        1964.896501
# 4        2014.000000
#             ...
# 13513    1981.000000
# 13514    1995.000000
# 13515    1997.000000
# 13516    1920.000000
# 13517    1920.000000
# Name: YearBuilt, Length: 13518, dtype: float64

# %%
df.fillna({
   "BuildingArea" : df["YearBuilt"].mean(),
    "YearBuilt" : df["YearBuilt"].mean()
    })
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13513     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13514  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13515     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13516   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13517   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0       1964.896501  1964.896501        Yarra -37.79960   144.99840
# 1         79.000000  1900.000000        Yarra -37.80790   144.99340
# 2        150.000000  1900.000000        Yarra -37.80930   144.99440
# 3       1964.896501  1964.896501        Yarra -37.79690   144.99690
# 4        142.000000  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13513   1964.896501  1981.000000          NaN -37.90562   145.16761
# 13514    133.000000  1995.000000          NaN -37.85927   144.87904
# 13515   1964.896501  1997.000000          NaN -37.85274   144.88738
# 13516    157.000000  1920.000000          NaN -37.85908   144.89299
# 13517    112.000000  1920.000000          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13513  South-Eastern Metropolitan        7392.0
# 13514        Western Metropolitan        6380.0
# 13515        Western Metropolitan        6380.0
# 13516        Western Metropolitan        6380.0
# 13517        Western Metropolitan        6543.0
#
# [13518 rows x 21 columns]

# %% [markdown]
# 5-VAZIFA. .groupby()¶
# Ustun uchun o'rta qiymat har doim ham aniq bo'lavermaydi. Keling avval YearBuilt ustuni uchun aniqroq qiymat topishga harakat qilamiz.
#
# Buning uchun Regionname ustuni qiymatlaridan foydalanishimiz mumkin, ya'ni bir Regiondagi binolar tahminan bir hil yillarda qurilgan deb tahmin qilsak bo'ladi.
#
# 5.1 .groupby() yordamida df qiymatlarini Regionname ustuni bo'yicha guruhlang va YaerBuilt ustuni uchun o'rta qiymatni hisoblang

# %%
df.groupby("Regionname").YearBuilt.mean().astype(int)
# Out:
# Regionname
# Eastern Metropolitan          1971
# Eastern Victoria              1984
# Northern Metropolitan         1962
# Northern Victoria             1986
# South-Eastern Metropolitan    1976
# Southern Metropolitan         1960
# Western Metropolitan          1968
# Western Victoria              1982
# Name: YearBuilt, dtype: int64

# %% [markdown]
# 5.2. df YearBuilt ustunidagi NaN qiymatlarni yuqoridagi qiymatlar bilan almashtiring.¶
# df[df.Regionname='Eastern Metropolitan']=...
#
# Har bir Regionname uchun qiymatlarni bittalab kiritmaslik uchun for siklidan foydalanishingiz mumkin

# %%
groups = df.groupby(['Regionname']).YearBuilt.mean() # Bu Series obyekti
for idx in groups.index:
   df[df.Regionname==idx] = df[df.Regionname==idx].fillna({'YearBuilt':groups[idx]})

# %%
groups
# Out:
# Regionname
# Eastern Metropolitan          1971.856106
# Eastern Victoria              1984.032258
# Northern Metropolitan         1962.965386
# Northern Victoria             1986.666667
# South-Eastern Metropolitan    1976.859504
# Southern Metropolitan         1960.887041
# Western Metropolitan          1968.236292
# Western Victoria              1982.565217
# Name: YearBuilt, dtype: float64

# %% [markdown]
# 6-VAZIFA. BuildingArea ustunidagi NaN qiymatlarni to'ldiramiz
# BuildingArea bino qurilgan yerning maydonini bildiradi. Bu qiymatlarni tahmin qilish uchun qaysi ustun qiymatlaridan foydalanish to'g'ri deb hisoblaysiz?

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13513     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13514  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13515     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13516   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13517   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN  1962.965386        Yarra -37.79960   144.99840
# 1              79.0  1900.000000        Yarra -37.80790   144.99340
# 2             150.0  1900.000000        Yarra -37.80930   144.99440
# 3               NaN  1962.965386        Yarra -37.79690   144.99690
# 4             142.0  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13513           NaN  1981.000000          NaN -37.90562   145.16761
# 13514         133.0  1995.000000          NaN -37.85927   144.87904
# 13515           NaN  1997.000000          NaN -37.85274   144.88738
# 13516         157.0  1920.000000          NaN -37.85908   144.89299
# 13517         112.0  1920.000000          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13513  South-Eastern Metropolitan        7392.0
# 13514        Western Metropolitan        6380.0
# 13515        Western Metropolitan        6380.0
# 13516        Western Metropolitan        6380.0
# 13517        Western Metropolitan        6543.0
#
# [13518 rows x 21 columns]

# %%
# 6.1 dfni xonalar soni bo'yicha o'rta qiymat olib ko'rin
rooms_mean = df["Rooms"].mean()
rooms_mean
# Out:
# 2.9397839917147506

# %%
# 6.2 Xonalar va uy turi bo'yicha o'rta qiymatni olib ko'ring.
df.groupby("Type").Rooms.mean()
# Out:
# Type
# h    3.265097
# t    2.837522
# u    1.964511
# Name: Rooms, dtype: float64

# %%
# 6.4 BuildingArea ustunidagi mavjud NaN qiymatlarni o'zingiz to'g'ri deb bilgan usul bilan to'ldiring.
df["BuildingArea"].fillna(method = "bfill", inplace = True)
df.head()
# Out:
# <ipython-input-30-cf7a75f83c96>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BuildingArea"].fillna(method = "bfill", inplace = True)
# <ipython-input-30-cf7a75f83c96>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["BuildingArea"].fillna(method = "bfill", inplace = True)
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0          79.0
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0         142.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#      YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0  1962.965386        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1  1900.000000        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2  1900.000000        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3  1962.965386        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4  2014.000000        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# 7-VAZIFA. Yuqoridagi vazifalardan so'ng, bizda faqatgina CouncilArea ustunida NaN qiymatlar qolishi kerak xolos.
# Bu ustundagi NaN qiymatlarni avvalgi qatordagi qiymatlar bilan to'ldirib keting. Natijani saqlab qoling

# %%
df["CouncilArea"].fillna(method = "ffill", inplace = True)
df.head()
# Out:
# <ipython-input-33-bd1054f9d862>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["CouncilArea"].fillna(method = "ffill", inplace = True)
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0          79.0
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0         142.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#      YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0  1962.965386        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1  1900.000000        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2  1900.000000        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3  1962.965386        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4  2014.000000        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# YAKUNIY JADVAL
# Ahamiyat bering, yakuniy jadvalda NaN qiymatlar bo'lmasligi kerak.

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64
