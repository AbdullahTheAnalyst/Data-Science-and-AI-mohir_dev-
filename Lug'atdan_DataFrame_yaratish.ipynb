# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/Lug'atdan_DataFrame_yaratish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
# lug'atdan DataFrame yaratish
data = ({
    "Uzbekistan" : {2024 : 20.13, 2023 : 15.3, 2022 : 14.8},
    "Tojikiston" : {2024 : 19.13, 2023 : 14.3, 2022 : 11.8},
})
df = pd.DataFrame (data)
df
# Out:
#       Uzbekistan  Tojikiston
# 2024       20.13       19.13
# 2023       15.30       14.30
# 2022       14.80       11.80

# %%
# bu funksiya orqali biz ustun va qator nomlarini alishtirib qo'yishimiz mumkin
df.T
# Out:
#              2024  2023  2022
# Uzbekistan  20.13  15.3  14.8
# Tojikiston  19.13  14.3  11.8

# %%
# Index nomini umumiy nomlab oldik.
df.index.name = "Yil kesimi:"

# %%
df
# Out:
#              Uzbekistan  Tojikiston
# Yil kesimi:
# 2024              20.13       19.13
# 2023              15.30       14.30
# 2022              14.80       11.80

# %%
# dataframening qiymatlari NumPy ichidagi array hosil bo'ladi va bu orqali ko'p amallarni bajarsak bo'ladi
df.values
# Out:
# array([[20.13, 19.13],
#        [15.3 , 14.3 ],
#        [14.8 , 11.8 ]])

# %%
df.index # indexlarni aniqlashtirdik
# Out:
# Index([2024, 2023, 2022], dtype='int64', name='Yil kesimi:')

# %%
"Uzbekistan" in df # in funksiyasi orqali df ichida shu so'z bor yoki yo'qligini tekshiradi
# Out:
# True

# %%
"Kazakistan" in df # in funksiyasi orqali df ichida shu so'z bor yoki yo'qligini tekshiradi
# Out:
# False
