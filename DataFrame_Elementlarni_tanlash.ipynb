# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/DataFrame_Elementlarni_tanlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
uz = {2024:37.5, 2023:36.4, 2022:34.7, 2021:33.5, 2020:32.6}
kz = {2024:34.5, 2023:37.4, 2022:31.7, 2021:34.5, 2020:38.6}
tj = {2024:31.5, 2023:30.4, 2022:30.7, 2021:31.5, 2020:37.6}
kg = {2024:38.5, 2023:31.4, 2022:33.7, 2021:37.5, 2020:30.6}
tr = {2024:37.5, 2023:32.4, 2022:39.7, 2021:38.5, 2020:34.6}
df = pd.DataFrame ({
    "Uzbekistan" : uz,
    "Kazakistan" : uz,
    "Tajikistan" : uz,
    "Kirgizistan" : uz,
    "Turkmanistan" : uz
})
df
# Out:
#       Uzbekistan  Kazakistan  Tajikistan  Kirgizistan  Turkmanistan
# 2024        37.5        37.5        37.5         37.5          37.5
# 2023        36.4        36.4        36.4         36.4          36.4
# 2022        34.7        34.7        34.7         34.7          34.7
# 2021        33.5        33.5        33.5         33.5          33.5
# 2020        32.6        32.6        32.6         32.6          32.6

# %%
# bitta [] bu Series ko'rinishida beradi
# ikkita [[]] bu dataframe ko'rinishida beradi
# bizga bu juda muhim. Sababi Series va DataFrame o'rtasidagi metodlar har xil
df [["Uzbekistan"]]
# Out:
#       Uzbekistan
# 2024        37.5
# 2023        36.4
# 2022        34.7
# 2021        33.5
# 2020        32.6

# %%
# oddiy numpy ga almshtirish yo'li
df ["Uzbekistan"].to_numpy()
# Out:
# array([37.5, 36.4, 34.7, 33.5, 32.6])

# %%
# 3-indexdan boshlab pastdagi qatorlarni chiqardik
df[3:]
# Out:
#       Uzbekistan  Kazakistan  Tajikistan  Kirgizistan  Turkmanistan
# 2021        33.5        33.5        33.5         33.5          33.5
# 2020        32.6        32.6        32.6         32.6          32.6

# %%
# 35 dan yuqori qiymatlarni ajratib oldik
df > 35.0
# Out:
#       Uzbekistan  Kazakistan  Tajikistan  Kirgizistan  Turkmanistan
# 2024        True        True        True         True          True
# 2023        True        True        True         True          True
# 2022       False       False       False        False         False
# 2021       False       False       False        False         False
# 2020       False       False       False        False         False

# %%
# 34 mln yuqori bo'lgan elementlarni filtr qilib chiqaryapmiz
df["Uzbekistan"][df["Uzbekistan"] > 34]
# Out:
# 2024    37.5
# 2023    36.4
# 2022    34.7
# Name: Uzbekistan, dtype: float64

# %%
# Rows bilan Columns joyini alaishtiriladi bu kod orqali
df1 = df.transpose (copy=True)
df1
# Out:
#               2024  2023  2022  2021  2020
# Uzbekistan    37.5  36.4  34.7  33.5  32.6
# Kazakistan    37.5  36.4  34.7  33.5  32.6
# Tajikistan    37.5  36.4  34.7  33.5  32.6
# Kirgizistan   37.5  36.4  34.7  33.5  32.6
# Turkmanistan  37.5  36.4  34.7  33.5  32.6
