# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahTheAnalyst/Data-Science-and-AI-mohir_dev-/blob/NumPy-and-Pandas/Dataframe_ma'lumotlar_tuzulmasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# dataframe ma'lumotlar tuzulmasining Series dan farqi shundaki, dataframening ustun va qatorlari bo'ladi
# dataframe asosan katta excel, csv fayllardan biz ochib olamiz, datalarni analiz qilish uchun

data = ({
    "Yil:" : [2024, 2023, 2022, 2021, 2020, 2019],
    "Aholi soni:" : [35.6, 33.4, 32.10, 31.24, 30.57, 29.6],
    "Temp:" : [1.2, 1.6, 1.5, 1.7, 1.9, 1.8]
})

df = pd.DataFrame (data)
df
# Out:
#    Yil:  Aholi soni:  Temp:
# 0  2024        35.60    1.2
# 1  2023        33.40    1.6
# 2  2022        32.10    1.5
# 3  2021        31.24    1.7
# 4  2020        30.57    1.9
# 5  2019        29.60    1.8

# %%
df.head()  # () ichiga hech nima yozmasak tepadan 5 ta qator chiqarib beradi
# Out:
#    Yil:  Aholi soni:  Temp:
# 0  2024        35.60    1.2
# 1  2023        33.40    1.6
# 2  2022        32.10    1.5
# 3  2021        31.24    1.7
# 4  2020        30.57    1.9

# %%
df.head(3)  #  tepadan 3 ta qator chiqarib beradi
# Out:
#    Yil:  Aholi soni:  Temp:
# 0  2024         35.6    1.2
# 1  2023         33.4    1.6
# 2  2022         32.1    1.5

# %%
df.shape  # bizga dataframe ning qator va ustunlar sonini ko'rsatadi
# Out:
# (6, 3)
